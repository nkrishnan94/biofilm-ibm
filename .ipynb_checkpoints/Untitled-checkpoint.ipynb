# %%
import numpy as np
import numpy as np
import glob
import os 
from datetime import datetime

import matplotlib.pyplot as plt
path = os.getcwd()

E = lambda e1,e2,sig,r: 4*(e1* ( (sig/r)**12-(sig/r)**6) )

F = lambda e1,e2,sig,r: -(24*e1*sig**6*(r**6-2*sig**6))/(r**13)

#E = lambda e1,e2,sig,r: 4*(e1* ( (sig/r)**12-(sig/r)**6) +e2*(sig/r)**2) # potential function

e1=1
e2=0
sig=1
N=10**6
r_min = .0005
r_space=np.linspace(r_min,2.5,N)

# %%
# %%latex
# \begin{equation}
# U(r) = 4 \epsilon [ \big(\frac{\sigma}{r}\big)^{12}-\big(\frac{\sigma}{r}\big)^{6}]
# \end{equation}
# \begin{equation}
# F(r) = 24 \epsilon*\frac{\sigma^6}{r^{13}}  *[ r^6 -2*\sigma^6]
# \end{equation}
# Out:
# \begin{equation}
# U(r) = 4 \epsilon [ \big(\frac{\sigma}{r}\big)^{12}-\big(\frac{\sigma}{r}\big)^{6}]
# \end{equation}
#
#
# \begin{equation}
# F(r) = 24 \epsilon*\frac{\sigma^6}{r^{13}}  *[ r^6 -2*\sigma^6]
# \end{equation}

# %%
f = np.loadtxt('interp.table',delimiter=" ")
p = np.loadtxt('potential.table',delimiter=" ")

# %%
fig,axs=plt.subplots(2,1,figsize=(8,8),sharex=True)
ax=axs[0]
ax.plot(r_space[380000:],E(e1,e2,sig,r_space)[380000:],color='grey',lw=3,label='U(r)')
ax.scatter(f[380000::40000,1],f[380000::40000,2],marker='x',s=140,label='LAMMPS linear interp.')
ax.scatter(p[382000::22000,1],p[382000::22000,2],marker='o',s=80,label='table input')
ax.grid()
#ax.set_xlabel('r',fontsize=16)
ax.set_ylabel('U',fontsize=16)

for axis in ['top','right']:
    ax.spines[axis].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.legend(fontsize=16)

ax=axs[1]

ax.plot(r_space[440000:],F(e1,e2,sig,r_space)[440000:],label='F(r)',color='gray',lw=3)
ax.scatter(f[440000::15000,1],f[440000::15000,3],marker='x',s=100,label='LAMMPS linear interp.')
ax.scatter(p[442000::15000,1],p[442000::15000,3],marker='o',s=50,label='table input')

ax.set_xlabel('r')
ax.set_ylabel('F')

ax.set_xlabel('r',fontsize=16)
ax.set_ylabel('F',fontsize=16)

for axis in ['top','right']:
    ax.spines[axis].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.grid()

# %%
# %%latex
# \begin{equation}
# U(r) = 4  [ \big(\frac{\sigma}{r}\big)^{12}\epsilon_1-\big(\frac{\sigma}{r}\big)^{6}\epsilon_1+\big(\frac{\sigma}{r}\big)^{2}\epsilon_2]
# \end{equation}
# Out:
# \begin{equation}
# U(r) = 4  [ \big(\frac{\sigma}{r}\big)^{12}\epsilon_1-\big(\frac{\sigma}{r}\big)^{6}\epsilon_1+\big(\frac{\sigma}{r}\big)^{2}\epsilon_2]
# \end{equation}

# %%
E = lambda e1,e2,sig,r: 4*(e1* ( (sig/r)**12-(sig/r)**6) +e2*(sig/r)**2)
e1=1.2
e2=.4
sig=.8
r=np.linspace(.8,4,1000)

# %%
fig,ax = plt.subplots(figsize=(8,8))
e1=3.4
e2=.8
sig=1
r=np.linspace(.98,4,1000)
ax.plot(r,E(e1,e2,sig,r),lw=3,c='darkgreen',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')
e1=2.5
e2=.5
sig=1
r=np.linspace(.98,4,1000)
ax.plot(r,E(e1,e2,sig,r),lw=3,c='navy',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')
#e1=1.2
#e2=.4
#sig=.8
#r=np.linspace(.8,4,1000)
#ax.plot(r,E(1.8,e2,sig,r),lw=3,c='purple',label='$\epsilon_1 = 1.2, \epsilon_2 = 0.4,\sigma=.8$')
e1=1
e2=0
s=1

ax.plot(r,E(e1,0,sig,r),lw=3,c='orange',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')
e1=2
e2=.35
sig=1
r=np.linspace(.98,4,1000)
ax.plot(r,E(e1,e2,sig,r),lw=3,c='purple',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')
#e1=1.2
#e2=0
#sig=.8
#r=np.linspace(.8,4,1000)
#ax.plot(r,E(1,0,sig,r),lw=3,c='darkgreen',label='$\epsilon_1 = 1.2, \sigma=.8$')
ax.grid()
for axis in ['top','right']:
    ax.spines[axis].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.set_xlabel('Distance',fontsize=16)
ax.set_ylabel('U',fontsize=16)
#plt.plot(r[1:],np.diff(E(e,sig,r)))
ax.legend(fontsize=14)
ax.text(4.1,1.5,
        r'$U(r) = 4  [ (\frac{\sigma}{r})^{12}\epsilon_1-(\frac{\sigma}{r})^{6}\epsilon_1+(\frac{\sigma}{r})^{2}\epsilon_2]$',
       fontsize=16)
#plt.title(r'$\epsilon_2 = 0$')
# Out:
# Text(4.1, 1.5, '$U(r) = 4  [ (\\frac{\\sigma}{r})^{12}\\epsilon_1-(\\frac{\\sigma}{r})^{6}\\epsilon_1+(\\frac{\\sigma}{r})^{2}\\epsilon_2]$')

# %%
fig,ax = plt.subplots()
e1=2
e2=.35
sig=1
r=np.linspace(.96,4,1000)
ax.plot(r,E(e1,e2,sig,r),lw=3,c='navy',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')
#e1=1.2
#e2=.4
#sig=.8
#r=np.linspace(.8,4,1000)
#ax.plot(r,E(1.8,e2,sig,r),lw=3,c='purple',label='$\epsilon_1 = 1.2, \epsilon_2 = 0.4,\sigma=.8$')
e1=1
e2=0
s=1

ax.plot(r,E(e1,0,sig,r),lw=3,c='orange',label='$\epsilon_1 ='+str( e1)+', \epsilon_2 ='+str(e2)+',\sigma= '+str(sig)+'$')

#e1=1.2
#e2=0
#sig=.8
#r=np.linspace(.8,4,1000)
#ax.plot(r,E(1,0,sig,r),lw=3,c='darkgreen',label='$\epsilon_1 = 1.2, \sigma=.8$')
ax.grid()
for axis in ['top','right']:
    ax.spines[axis].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.set_xlabel('Distance',fontsize=16)
ax.set_ylabel('U',fontsize=16)
#plt.plot(r[1:],np.diff(E(e,sig,r)))
ax.legend()
ax.text(5,4,
        r'$U(r) = 4  [ (\frac{\sigma}{r})^{12}\epsilon_1-(\frac{\sigma}{r})^{6}\epsilon_1+(\frac{\sigma}{r})^{2}\epsilon_2]$',
       fontsize=16)
#plt.title(r'$\epsilon_2 = 0$')
# Out:
# Text(5, 4, '$U(r) = 4  [ (\\frac{\\sigma}{r})^{12}\\epsilon_1-(\\frac{\\sigma}{r})^{6}\\epsilon_1+(\\frac{\\sigma}{r})^{2}\\epsilon_2]$')

# %%
E = lambda e1,e2,sig,r: 4*(e1* ( (sig/r)**12-(sig/r)**6) +e2*(sig/r)**2)

# %%
F = lambda a,b,sig,r:  -4*(-(12*a*sig**12)/r**13 + (6*a*sig**6)/r**7 - (2*b*sig**2)/r**3)

# %%
fig,ax = plt.subplots()
ax.plot(r,F(1.8,e2,sig,r),lw=3,c='navy',label='$\epsilon_2 = 0.2$')
ax.plot(r,F(1,0,sig,r),lw=3,c='orange',label='$\epsilon_2 = 0$')
ax.grid()
for axis in ['top','right']:
    ax.spines[axis].set_visible(False)
for axis in ['bottom','left']:
    ax.spines[axis].set_linewidth(3)
ax.tick_params(axis='both', which='major', labelsize=14)
ax.set_xlabel('Distance',fontsize=16)
ax.set_ylabel('U',fontsize=16)
#plt.plot(r[1:],np.diff(E(e,sig,r)))
ax.legend()

#plt.title(r'$\epsilon_2 = 0$')
