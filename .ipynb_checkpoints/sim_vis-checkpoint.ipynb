# %%
import numpy as np
import glob
import os

import numpy as np
import glob
import os
import matplotlib.pyplot as plt






from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


import matplotlib.pyplot as plt
import numpy as np

# %%
E = lambda r0,r,a, D, r1: D* ( np.exp(-2*a*(r-r0)) -2 *np.exp(-a*(r-r0)))
Eprime = lambda r0,r,a, D, r1: -2*a*D* np.exp(a * (r0-r) ) * (np.exp(a * (r0-r) ) - 1)
E = lambda r0,r,a, D, r1: D* ( np.exp(-2*a*(r-r0)) -2 *np.exp(-a*(r-r0)))
Eprime = lambda r0,r,a, D, r1: -2*a*D* np.exp(a * (r0-r) ) * (np.exp(a * (r0-r) ) - 1)

# %%
(4.125*2.5*2)+np.log(2)/a
# Out:
# 34.4879436111989

# %%
a = .02

r0 = (4.125*2.5*2)
D=.1

r1 = 2*4.125*2.5*1.4
r = np.linspace(1.5*2.5*4.125,2*4.125*2.5*3,1000)
E(r0,r,a,D,r1);

# %%
r0
# Out:
# 20.625

# %%
plt.plot(r/(4.125*2.5*2),Eprime(r0,r,a,D,r1))

# %%
file = "output.bp"

# %%
f = open(file)

# %%
t_str = []
with open (file) as myfile:
    i=0
    for line in myfile:
        if i==1:
            t_str.append(line)
            i=0
        if "ITEM: TIMESTEP\n" in line:
            i=1

# %%
t_arr = [int(i) for i in t_str]

# %%
len(t_arr)
# Out:
# 1001

# %%
cell_arr  = np.zeros((len(t_arr) - 1,6851, 9))
for t in range(len(t_arr)-1):
    i=0
    i_end=t
    cell_str = []
    with open (file) as myfile:
        for line in myfile:

            if ("ITEM: ATOMS" in line) and (i==i_end):
                break

            if ("ITEM: ATOMS" in line) and (i<i_end):
                i+=1

        for line in myfile:
            if "ITEM: TIMESTEP" in line:
                break
            cell_str.append(line)
            
            
    cell_arr[t] = np.array([np.array(cell_str[i].split( )[1:]).astype(float) for i in range(len(cell_str))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2029-d3ba55652388> in <module>
#      19
#      20
# ---> 21     cell_arr[t] = np.array([np.array(cell_str[i].split( )[1:]).astype(float) for i in range(len(cell_str))])
#      22
#      23
#
# ValueError: could not broadcast input array from shape (6513,9) into shape (6851,9)

# %%
fig = plt.figure(figsize=(20,4))
ax = fig.add_subplot(111, projection='3d')



n = 300

t = 13
xlim=90
ylim = 1400
zlim=300
# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=cell_arr[t,:,0].flatten()*xlim
y= cell_arr[t,:,1].flatten()*ylim
z=cell_arr[t,:,2].flatten()*zlim
f = np.sum(cell_arr[t,:,7:]**2,axis=1)**.5

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,100])
ax.set_ylim([0,1400])

ax.set_zlim([0,500])



im = ax.scatter(x, y, z,c=np.log(f),s=40,
                vmin=np.log(np.min(np.sum(cell_arr[:,:,7:]**2,axis=2)**.5)),
                vmax=np.log(np.max(np.sum(cell_arr[:,:,7:]**2,axis=2)**.5)),
                cmap='viridis');
ax.view_init(0, 360)

print(f)


plt.show()
# Out:
# <ipython-input-2030-e6bdb09dd4fd>:31: RuntimeWarning: divide by zero encountered in log
#   im = ax.scatter(x, y, z,c=np.log(f),s=40,
# <ipython-input-2030-e6bdb09dd4fd>:32: RuntimeWarning: divide by zero encountered in log
#   vmin=np.log(np.min(np.sum(cell_arr[:,:,7:]**2,axis=2)**.5)),
# [0. 0. 0. ... 0. 0. 0.]
# <ipython-input-2030-e6bdb09dd4fd>:33: RuntimeWarning: divide by zero encountered in log
#   vmax=np.log(np.max(np.sum(cell_arr[:,:,7:]**2,axis=2)**.5)),

# %%
t = 1000#len(t_arr)-1
i=0
i_end=t
cell_str = []
with open (file) as myfile:
    for line in myfile:

        if ("ITEM: ATOMS" in line) and (i==i_end):
            break

        if ("ITEM: ATOMS" in line) and (i<i_end):
            i+=1

    for line in myfile:
        if "ITEM: TIMESTEP" in line:
            break
        cell_str.append(line)


cell_arr = np.array([np.array(cell_str[i].split( )[1:]).astype(float) for i in range(len(cell_str))])

fig = plt.figure(figsize=(20,4))
ax = fig.add_subplot(111, projection='3d')


xlim=90
ylim = 1400
zlim=150
# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=cell_arr[:,0].flatten()*xlim
y= cell_arr[:,1].flatten()*ylim
z=cell_arr[:,2].flatten()*zlim
f = np.sum(cell_arr[:,6:]**2,axis=1)**.5
fx = cell_arr[:,6]
fy = cell_arr[:,7]
fz = cell_arr[:,8]

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,90])
ax.set_ylim([0,1400])

ax.set_zlim([0,500])



im = ax.scatter(x, y, z,c=f,s=1,
                vmin=np.min(f),
                vmax=np.max(f),
                cmap='viridis')
ax.view_init(0, 360)
plt.colorbar(im)



plt.show()

# %%
plt.plot(cell_arr[:,1])

# %%
t = 20#len(t_arr)-1
i=0
i_end=t
cell_str = []
with open (file) as myfile:
    for line in myfile:

        if ("ITEM: ATOMS" in line) and (i==i_end):
            break

        if ("ITEM: ATOMS" in line) and (i<i_end):
            i+=1

    for line in myfile:
        if "ITEM: TIMESTEP" in line:
            break
        cell_str.append(line)


cell_arr = np.array([np.array(cell_str[i].split( )[1:]).astype(float) for i in range(len(cell_str))])

fig = plt.figure(figsize=(20,4))
ax = fig.add_subplot(111, projection='3d')


xlim=90
ylim = 1400
zlim=150
# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
#for m in arr:
#    ax.scatter(*m[1:4],s= (m[4])**2,cmap='viridis')
x=cell_arr[:,0].flatten()*xlim
y= cell_arr[:,1].flatten()*ylim
z=cell_arr[:,2].flatten()*zlim
f = np.sum(cell_arr[:,6:]**2,axis=1)**.5
fx = cell_arr[:,6]
fy = cell_arr[:,7]
fz = cell_arr[:,8]

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_xlim([0,100])
ax.set_ylim([0,1400])

ax.set_zlim([0,500])



im = ax.scatter(x, y, z,c=fy,s=40,
                vmin=np.min(fy),
                vmax=np.max(fy),
                cmap='viridis')
ax.view_init(-10, 360)
plt.colorbar(im)


plt.show()

# %%
cell_arr[:,2]
# Out:
# array([0.0670212, 0.937557 , 0.0530814, ..., 0.910084 , 0.78479  ,
#        0.869091 ])

# %%
line
# Out:
# '6483 0.942506 0.985888 0.950347 0 0 0 -0.00268187 0.0877156 0.350248 \n'

# %%
z
# Out:
# array([286.1148, 292.1961, 291.6669, ..., 287.4093, 289.647 , 283.7172])
